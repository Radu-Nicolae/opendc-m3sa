# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
validation = pd.read_parquet("../_footprinter-exp-1/validation/surfsara.parquet")
validation = validation.groupby("timestamp").sum()
simulation = pd.read_parquet("../exp1-fig1/outputs/raw-output/0/seed=0/host.parquet")
simulation = simulation.select_dtypes(include=[np.number]).groupby("timestamp").sum()

# %%
validation.plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
# select only power_draw and energy_usage
simulation_relevant = simulation[["power_draw", "energy_usage"]]
simulation_relevant.plot()
# Out:
# <Axes: xlabel='timestamp'>
